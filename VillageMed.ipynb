# %%
import pandas as pd
import numpy as np

# %%
#This dataset, named df1 contains medical error data from a Nigerian hospital
# This dataset, named df2 contains medical error data from three Eastern African Hospitals

df1 = pd.read_csv("C:/Users/hp/Desktop/data 1.csv")
df2 = pd.read_csv("C:/Users/hp/Desktop/data 2.csv")

# %% [markdown]
# **2. Data Cleaning Notebook**

# %%
#Data Preprocessing: both data need to have the same column called "Region"
df1["Region"] = "West Africa"

# %%
df2["Region"] = "East Africa"

# %%
# Combine them into one dataframe
df = pd.concat([df1, df2], ignore_index=True)

# %%
df.head()
# Out:
#    patient_id hospital_facility_type  state  country reporting_staff_role  \
# 0           1      Tertiary Hospital   Kano  Nigeria                Nurse
# 1           2       General Hospital  Lagos  Nigeria                Nurse
# 2           3      Teaching Hospital    FCT  Nigeria           Pharmacist
# 3           4      Teaching Hospital    Imo  Nigeria                Nurse
# 4           5      Teaching Hospital    Edo  Nigeria               Doctor
#
#    patient_age patient_gender           error_type             error_subtype  \
# 0           43           Male     Medication Error              Omitted Dose
# 1           59         Female  Documentation Error       Wrong Patient Chart
# 2           26         Female  Documentation Error           Illegible Order
# 3           37         Female     Surgical Mistake             Post-op Bleed
# 4            0           Male     Diagnostic Error  Result Misinterpretation
#
#     department severity_level         outcome         detection_method  \
# 0     Pharmacy          Minor  Temporary Harm        Patient Complaint
# 1  Orthopedics          Minor         No Harm  Electronic System Alert
# 2     Pharmacy       Moderate           Death  Electronic System Alert
# 3     Pharmacy       Moderate  Temporary Harm  Electronic System Alert
# 4  Orthopedics          Minor           Death              Self-report
#
#   contributing_factor          report_source      corrective_action  \
# 0        System Error  Internal Hospital Log    Root Cause Analysis
# 1    Miscommunication  Internal Hospital Log         Staff Training
# 2      Staff Shortage         Ministry Audit  Equipment Maintenance
# 3   Equipment Failure  Internal Hospital Log  Equipment Maintenance
# 4             Fatigue  Internal Hospital Log         Staff Training
#
#         Region facility_type
# 0  West Africa           NaN
# 1  West Africa           NaN
# 2  West Africa           NaN
# 3  West Africa           NaN
# 4  West Africa           NaN

# %%
#Data Cleaning: Column titles must be properly aligned to remove trailing spaces

df.columns = df.columns.str.strip().str.title()

# %%
df.head(10)
# Out:
#    Patient_Id Hospital_Facility_Type   State  Country Reporting_Staff_Role  \
# 0           1      Tertiary Hospital    Kano  Nigeria                Nurse
# 1           2       General Hospital   Lagos  Nigeria                Nurse
# 2           3      Teaching Hospital     FCT  Nigeria           Pharmacist
# 3           4      Teaching Hospital     Imo  Nigeria                Nurse
# 4           5      Teaching Hospital     Edo  Nigeria               Doctor
# 5           6      Tertiary Hospital    Kano  Nigeria              Midwife
# 6           7      Tertiary Hospital  Kaduna  Nigeria        Lab Scientist
# 7           8      Tertiary Hospital     Edo  Nigeria               Doctor
# 8           9      Teaching Hospital  Kaduna  Nigeria        Lab Scientist
# 9          10    Specialist Hospital    Ogun  Nigeria                Nurse
#
#    Patient_Age Patient_Gender           Error_Type             Error_Subtype  \
# 0           43           Male     Medication Error              Omitted Dose
# 1           59         Female  Documentation Error       Wrong Patient Chart
# 2           26         Female  Documentation Error           Illegible Order
# 3           37         Female     Surgical Mistake             Post-op Bleed
# 4            0           Male     Diagnostic Error  Result Misinterpretation
# 5           52           Male  Documentation Error         Incomplete Record
# 6           14           Male     Surgical Mistake                Wrong Site
# 7           41           Male  Documentation Error       Wrong Patient Chart
# 8           55         Female     Medication Error                Wrong Drug
# 9           41           Male  Documentation Error           Illegible Order
#
#           Department Severity_Level         Outcome         Detection_Method  \
# 0           Pharmacy          Minor  Temporary Harm        Patient Complaint
# 1        Orthopedics          Minor         No Harm  Electronic System Alert
# 2           Pharmacy       Moderate           Death  Electronic System Alert
# 3           Pharmacy       Moderate  Temporary Harm  Electronic System Alert
# 4        Orthopedics          Minor           Death              Self-report
# 5  Internal Medicine          Minor         No Harm                    Audit
# 6  Internal Medicine         Severe  Temporary Harm              Self-report
# 7          Emergency          Minor  Temporary Harm              Self-report
# 8          Emergency       Moderate         No Harm              Self-report
# 9           Pharmacy          Minor         No Harm              Self-report
#
#   Contributing_Factor          Report_Source        Corrective_Action  \
# 0        System Error  Internal Hospital Log      Root Cause Analysis
# 1    Miscommunication  Internal Hospital Log           Staff Training
# 2      Staff Shortage         Ministry Audit    Equipment Maintenance
# 3   Equipment Failure  Internal Hospital Log    Equipment Maintenance
# 4             Fatigue  Internal Hospital Log           Staff Training
# 5        Training Gap         Patient Report    Equipment Maintenance
# 6      Staff Shortage  Internal Hospital Log      Root Cause Analysis
# 7        System Error         Ministry Audit           Staff Training
# 8        System Error         Patient Report  Digital Record Adoption
# 9   Equipment Failure         Ministry Audit  Digital Record Adoption
#
#         Region Facility_Type
# 0  West Africa           NaN
# 1  West Africa           NaN
# 2  West Africa           NaN
# 3  West Africa           NaN
# 4  West Africa           NaN
# 5  West Africa           NaN
# 6  West Africa           NaN
# 7  West Africa           NaN
# 8  West Africa           NaN
# 9  West Africa           NaN

# %%
#checking for missing data/values
df.isnull()
# Out:
#      Patient_Id  Hospital_Facility_Type  State  Country  Reporting_Staff_Role  \
# 0         False                   False  False    False                 False
# 1         False                   False  False    False                 False
# 2         False                   False  False    False                 False
# 3         False                   False  False    False                 False
# 4         False                   False  False    False                 False
# ..          ...                     ...    ...      ...                   ...
# 549       False                    True  False    False                 False
# 550       False                    True  False    False                 False
# 551       False                    True  False    False                 False
# 552       False                    True  False    False                 False
# 553       False                    True  False    False                 False
#
#      Patient_Age  Patient_Gender  Error_Type  Error_Subtype  Department  \
# 0          False           False       False          False       False
# 1          False           False       False          False       False
# 2          False           False       False          False       False
# 3          False           False       False          False       False
# 4          False           False       False          False       False
# ..           ...             ...         ...            ...         ...
# 549        False           False       False          False       False
# 550        False           False       False          False       False
# 551        False           False       False          False       False
# 552        False           False       False          False       False
# 553        False           False       False          False       False
#
#      Severity_Level  Outcome  Detection_Method  Contributing_Factor  \
# 0             False    False             False                False
# 1             False    False             False                False
# 2             False    False             False                False
# 3             False    False             False                False
# 4             False    False             False                False
# ..              ...      ...               ...                  ...
# 549           False    False             False                False
# 550           False    False             False                False
# 551           False    False             False                False
# 552           False    False             False                False
# 553           False    False             False                False
#
#      Report_Source  Corrective_Action  Region  Facility_Type
# 0            False              False   False           True
# 1            False              False   False           True
# 2            False              False   False           True
# 3            False              False   False           True
# 4            False              False   False           True
# ..             ...                ...     ...            ...
# 549          False              False   False          False
# 550          False              False   False          False
# 551          False              False   False          False
# 552          False              False   False          False
# 553          False              False   False          False
#
# [554 rows x 18 columns]

# %%
#checking for duplicates
df.duplicated().any()
# Out:
# np.False_

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554 entries, 0 to 553
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Patient_Id              554 non-null    int64
#  1   Hospital_Facility_Type  277 non-null    object
#  2   State                   554 non-null    object
#  3   Country                 554 non-null    object
#  4   Reporting_Staff_Role    554 non-null    object
#  5   Patient_Age             554 non-null    int64
#  6   Patient_Gender          554 non-null    object
#  7   Error_Type              554 non-null    object
#  8   Error_Subtype           554 non-null    object
#  9   Department              554 non-null    object
#  10  Severity_Level          554 non-null    object
#  11  Outcome                 554 non-null    object
#  12  Detection_Method        554 non-null    object
#  13  Contributing_Factor     554 non-null    object
#  14  Report_Source           554 non-null    object
#  15  Corrective_Action       554 non-null    object
#  16  Region                  554 non-null    object
#  17  Facility_Type           277 non-null    object
# dtypes: int64(2), object(16)
# memory usage: 78.0+ KB

# %%
#Data Cleaning: Two columns are identical, hence one has to be dropped
df = df.drop(columns=["Facility_Type"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554 entries, 0 to 553
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Patient_Id              554 non-null    int64
#  1   Hospital_Facility_Type  277 non-null    object
#  2   State                   554 non-null    object
#  3   Country                 554 non-null    object
#  4   Reporting_Staff_Role    554 non-null    object
#  5   Patient_Age             554 non-null    int64
#  6   Patient_Gender          554 non-null    object
#  7   Error_Type              554 non-null    object
#  8   Error_Subtype           554 non-null    object
#  9   Department              554 non-null    object
#  10  Severity_Level          554 non-null    object
#  11  Outcome                 554 non-null    object
#  12  Detection_Method        554 non-null    object
#  13  Contributing_Factor     554 non-null    object
#  14  Report_Source           554 non-null    object
#  15  Corrective_Action       554 non-null    object
#  16  Region                  554 non-null    object
# dtypes: int64(2), object(15)
# memory usage: 73.7+ KB

# %% [markdown]
# **3. SUMMARY STAT**

# %%
#frequency distribution(Counts) of Error_types
df["Error_Type"].value_counts()
# Out:
# Error_Type
# Medication Error           211
# Surgical Mistake            95
# Diagnostic Error            78
# Documentation Error         66
# Infection Control Error     41
# Device/Equipment Error      37
# Transfusion Error           26
# Name: count, dtype: int64

# %%
#percentage distribution of error types
print(df["Error_Type"].value_counts(normalize=True) * 100)
# Out:
# Error_Type
# Medication Error           38.086643
# Surgical Mistake           17.148014
# Diagnostic Error           14.079422
# Documentation Error        11.913357
# Infection Control Error     7.400722
# Device/Equipment Error      6.678700
# Transfusion Error           4.693141
# Name: proportion, dtype: float64

# %%
#frequency distribution(Counts) of Hospital_Facility_Type
df["Hospital_Facility_Type"].value_counts()
# Out:
# Hospital_Facility_Type
# Specialist Hospital    79
# Teaching Hospital      76
# Tertiary Hospital      75
# General Hospital       47
# Name: count, dtype: int64

# %%
#percentage distribution of Hospital Facility types
print(df["Hospital_Facility_Type"].value_counts(normalize=True) * 100)
# Out:
# Hospital_Facility_Type
# Specialist Hospital    28.519856
# Teaching Hospital      27.436823
# Tertiary Hospital      27.075812
# General Hospital       16.967509
# Name: proportion, dtype: float64

# %%
#Count and Percentage distribution of medical error by country

Country_Distribution = (
    df.groupby("Country")
    .size()
    .reset_index(name="Count")
)

Country_Distribution["Percentage"] = (Country_Distribution["Count"] / Country_Distribution["Count"].sum()) * 100

# %%
Country_Distribution
# Out:
#     Country  Count  Percentage
# 0     Kenya     96   17.328520
# 1   Nigeria    277   50.000000
# 2  Tanzania     82   14.801444
# 3    Uganda     99   17.870036

# %% [markdown]
# **4 . VISUALIZATION**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **3 Visualizations: Bar (errors by type), Heatmap (errors by state vs error type), Pie (error
# proportions).**

# %%
#Count of Error types
Error_counts = df["Error_Type"].value_counts()

# %%
Error_counts
# Out:
# Error_Type
# Medication Error           211
# Surgical Mistake            95
# Diagnostic Error            78
# Documentation Error         66
# Infection Control Error     41
# Device/Equipment Error      37
# Transfusion Error           26
# Name: count, dtype: int64

# %%
#Horizontal bar chart of Error types
Error_counts.plot(kind="barh", color="skyblue", figsize=(8,5))
plt.xlabel("Number of Errors")      # X-axis label
plt.ylabel("Error Type")            # Y-axis label
plt.title("Distribution of Errors by Type")  # Chart title
# Out:
# Text(0.5, 1.0, 'Distribution of Errors by Type')

# %%
#We need to count errors for each State and Error_Type.

Error_matrix = pd.crosstab(df["State"], df["Error_Type"])
Error_matrix
# Out:
# Error_Type     Device/Equipment Error  Diagnostic Error  Documentation Error  \
# State
# Arusha                              3                 2                    5
# Dar es Salaam                       2                 3                    2
# Dodoma                              2                 2                    2
# Edo                                 1                 5                    3
# Enugu                               3                 4                    4
# FCT                                 0                 0                    5
# Imo                                 0                 4                    4
# Kaduna                              4                 6                    2
# Kampala                             1                 6                    1
# Kano                                2                 2                    4
# Kisii                               2                 5                    4
# Kisumu                              3                 3                    3
# Lagos                               0                 5                    3
# Mbale                               5                 4                    3
# Mbarara                             2                 4                    4
# Nairobi                             0                 7                    5
# Ogun                                1                 1                    4
# Oyo                                 1                 7                    4
# Plateau                             4                 6                    2
# Rivers                              1                 2                    2
#
# Error_Type     Infection Control Error  Medication Error  Surgical Mistake  \
# State
# Arusha                               4                 9                 5
# Dar es Salaam                        1                11                12
# Dodoma                               2                 9                 6
# Edo                                  3                13                 5
# Enugu                                1                13                 3
# FCT                                  2                10                 3
# Imo                                  2                10                 5
# Kaduna                               2                 7                 2
# Kampala                              5                10                 6
# Kano                                 3                11                 6
# Kisii                                3                12                 4
# Kisumu                               2                 9                 3
# Lagos                                0                 6                 3
# Mbale                                3                16                 5
# Mbarara                              0                13                11
# Nairobi                              3                11                 2
# Ogun                                 2                 6                 4
# Oyo                                  0                13                 1
# Plateau                              1                12                 4
# Rivers                               2                10                 5
#
# Error_Type     Transfusion Error
# State
# Arusha                         1
# Dar es Salaam                  1
# Dodoma                         1
# Edo                            2
# Enugu                          1
# FCT                            1
# Imo                            1
# Kaduna                         1
# Kampala                        3
# Kano                           1
# Kisii                          2
# Kisumu                         3
# Lagos                          0
# Mbale                          2
# Mbarara                        0
# Nairobi                        2
# Ogun                           0
# Oyo                            1
# Plateau                        2
# Rivers                         1

# %%
#Plot the heatmap
plt.figure(figsize=(10,6))  

sns.heatmap(Error_matrix, annot=True, fmt="d", cmap="Blues")

plt.title("Errors by State vs Error Type")
plt.xlabel("Error Type")
plt.ylabel("State")
plt.show()

# %%
# Count error types
Error_counts = df["Error_Type"].value_counts()

# Plot pie chart
plt.figure(figsize=(6,6))
plt.pie(
    Error_counts, 
    labels=Error_counts.index, 
    autopct="%1.1f%%",   # show percentages with 1 decimal
    startangle=90        # rotate chart so first slice starts at the top
)

plt.title("Error_Type Proportions")
plt.show()
